# %%
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\antuk\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow as tf
import warnings  # Import the warnings module

if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please ensure you have installed TensorFlow correctly')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# C:\Users\antuk\AppData\Local\Temp\ipykernel_17348\1496822024.py:5: UserWarning: No GPU found. Please ensure you have installed TensorFlow correctly
#   warnings.warn('No GPU found. Please ensure you have installed TensorFlow correctly')

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- --------------------
# absl-py                      2.1.0
# anyio                        4.2.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.1.0
# Babel                        2.11.0
# beautifulsoup4               4.12.2
# bleach                       4.1.0
# Brotli                       1.0.9
# cachetools                   5.3.3
# certifi                      2024.2.2
# cffi                         1.16.0
# chardet                      5.2.0
# charset-normalizer           2.0.4
# colorama                     0.4.6
# comm                         0.2.1
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.6.7
# decorator                    5.1.1
# defusedxml                   0.7.1
# exceptiongroup               1.2.0
# executing                    0.8.3
# fastjsonschema               2.16.2
# filelock                     3.14.0
# flatbuffers                  24.3.25
# fonttools                    4.51.0
# fsspec                       2024.3.1
# gast                         0.4.0
# google-auth                  2.29.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.62.2
# h5py                         3.11.0
# idna                         3.4
# intel-openmp                 2021.4.0
# ipykernel                    6.28.0
# ipython                      8.20.0
# jedi                         0.18.1
# Jinja2                       3.1.3
# json5                        0.9.6
# jsonschema                   4.19.2
# jsonschema-specifications    2023.7.1
# jupyter_client               8.6.0
# jupyter_core                 5.5.0
# jupyter-events               0.8.0
# jupyter-lsp                  2.2.0
# jupyter_server               2.10.0
# jupyter_server_terminals     0.4.4
# jupyterlab                   4.0.11
# jupyterlab-pygments          0.1.2
# jupyterlab_server            2.25.1
# keras                        2.10.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.5
# libclang                     18.1.1
# Markdown                     3.6
# MarkupSafe                   2.1.3
# matplotlib                   3.8.4
# matplotlib-inline            0.1.6
# mistune                      2.0.4
# mkl                          2021.4.0
# mpmath                       1.3.0
# nbclient                     0.8.0
# nbconvert                    7.10.0
# nbformat                     5.9.2
# nest-asyncio                 1.6.0
# networkx                     3.3
# notebook                     7.0.8
# notebook_shim                0.2.3
# numpy                        1.26.4
# oauthlib                     3.2.2
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# overrides                    7.4.0
# packaging                    23.2
# pandas                       2.2.2
# pandocfilters                1.5.0
# parso                        0.8.3
# pillow                       10.3.0
# pip                          23.3.1
# platformdirs                 3.10.0
# prometheus-client            0.14.1
# prompt-toolkit               3.0.43
# protobuf                     3.19.6
# psutil                       5.9.0
# pure-eval                    0.2.2
# py-cpuinfo                   9.0.0
# pyasn1                       0.6.0
# pyasn1_modules               0.4.0
# pycparser                    2.21
# Pygments                     2.15.1
# pyparsing                    3.1.2
# PySocks                      1.7.1
# python-dateutil              2.8.2
# python-json-logger           2.0.7
# pytz                         2023.3.post1
# pywin32                      305.1
# pywinpty                     2.0.10
# PyYAML                       6.0.1
# pyzmq                        25.1.2
# referencing                  0.30.2
# requests                     2.31.0
# requests-oauthlib            2.0.0
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.10.6
# rsa                          4.9
# scipy                        1.13.0
# seaborn                      0.13.2
# Send2Trash                   1.8.2
# setuptools                   68.2.2
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.5
# stack-data                   0.2.0
# sympy                        1.12
# tbb                          2021.12.0
# tensorboard                  2.10.1
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.10.0
# tensorflow-estimator         2.10.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# terminado                    0.17.1
# thop                         0.1.1.post2209072238
# tinycss2                     1.2.1
# tomli                        2.0.1
# torch                        2.3.0
# torchvision                  0.18.0
# tornado                      6.3.3
# tqdm                         4.66.2
# traitlets                    5.7.1
# typing_extensions            4.11.0
# tzdata                       2024.1
# urllib3                      2.1.0
# wcwidth                      0.2.5
# webencodings                 0.5.1
# websocket-client             0.58.0
# Werkzeug                     3.0.2
# wheel                        0.41.2
# win-inet-pton                1.1.0
# wrapt                        1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import pandas as pd
from ultralytics import YOLO

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.12-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#      ------------------------------ --------- 30.7/40.7 kB 1.3 MB/s eta 0:00:01
#      ------------------------------ --------- 30.7/40.7 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 40.7/40.7 kB 243.6 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (0.18.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from requests>=2.23.0->ultralytics) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\antuk\anaconda3\envs\tensorflowgpu\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.12-py3-none-any.whl (756 kB)
#    ---------------------------------------- 0.0/756.4 kB ? eta -:--:--
#    --- ------------------------------------ 71.7/756.4 kB 3.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 204.8/756.4 kB 2.1 MB/s eta 0:00:01
#    ------------- -------------------------- 256.0/756.4 kB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 460.8/756.4 kB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 716.8/756.4 kB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 737.3/756.4 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 756.4/756.4 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: ultralytics
# Successfully installed ultralytics-8.2.12
